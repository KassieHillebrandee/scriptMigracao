# %% [markdown]
# ## Declarações e imports

# %%
import pandas, sqlalchemy, numpy
import xml.etree.cElementTree as et

# %% [markdown]
# ### Funções de tratamento

# %%
def tratamentoTelefone(telefone):
    intab = '()- '
    outtab = '    '
    transtab = str.maketrans(intab,outtab)
    return '+55'+str(telefone).translate(transtab).replace(' ','') 

def tratamentoValor(valor):
    x = lambda x: 'R$ {:.2f}'.format(float(x)).replace('.',',')
    intab = 'R$Ss'
    outtab = '    '
    transtab = str.maketrans(intab,outtab)
    return (x(valor) if str(valor).isdigit() else x(str(valor).translate(transtab).replace(',','.')))

def validaCastNumerico(valor):
    intab = 'R$Ss-'
    outtab = '     '
    transtab = str.maketrans(intab,outtab)
    valor = str(valor).replace(',','.')
    valor.translate(transtab)
    return (float(valor) if valor.isdigit() else 0)

## Não houve campo algum de data para converter para DateTime, contudo seria apenas usar 
## dataframe['campo'] = dataframe['campo'].apply(lambda x: pd.to_datetime(x))

defaultColumns = ['id','name','email','phone','value','discount', 'valor_com_desconto']

# %% [markdown]
# ## Import do primeiro arquivo
# Arquivo CSV

# %%
file = './dataApr-1-2019.csv'
file1 = pandas.read_csv(file, sep=';')
file1.head(5)
# Out:
#    client_id       username                     email_client    phone_client  \
# 0       1000  Cynthia Renee  nulla@sitametconsectetuer.co.uk  (051) 702-7535
# 1       1001    Kevin Zahir                Cras@justosit.org  (282) 366-4062
# 2       1002  Marvin Tucker         nec@nislsemconsequat.net  (059) 080-6768
# 3       1003  Olympia Blake                 malesuada@at.edu  (928) 633-3253
# 4       1004  Wallace Ethan    sem.molestie@urnasuscipit.net  (994) 324-9907
#
#    product_value  discount
# 0          75.82        66
# 1          44.54        23
# 2          17.12        74
# 3           6.15        33
# 4          99.76        49

# %% [markdown]
# ## tratamento dos dados do primeiro arquivo

# %%
file1['valor_com_desconto'] = (file1['product_value'].apply(lambda x : float(x)) - file1['discount'].apply(lambda x : float(x)))
file1['phone_client'] = file1['phone_client'].apply(lambda x : tratamentoTelefone(x))
file1['product_value'] = file1['product_value'].apply(lambda x : tratamentoValor(x))
file1['discount'] = file1['discount'].apply(lambda x : tratamentoValor(x))
file1['valor_com_desconto'] = file1['valor_com_desconto'].apply(lambda x : tratamentoValor(x))
file1.columns = defaultColumns
file1.head(5)
# Out:
#      id           name                            email          phone  \
# 0  1000  Cynthia Renee  nulla@sitametconsectetuer.co.uk  +550517027535
# 1  1001    Kevin Zahir                Cras@justosit.org  +552823664062
# 2  1002  Marvin Tucker         nec@nislsemconsequat.net  +550590806768
# 3  1003  Olympia Blake                 malesuada@at.edu  +559286333253
# 4  1004  Wallace Ethan    sem.molestie@urnasuscipit.net  +559943249907
#
#       value  discount valor_com_desconto
# 0  R$ 75,82  R$ 66,00            R$ 9,82
# 1  R$ 44,54  R$ 23,00           R$ 21,54
# 2  R$ 17,12  R$ 74,00          R$ -56,88
# 3   R$ 6,15  R$ 33,00          R$ -26,85
# 4  R$ 99,76  R$ 49,00           R$ 50,76

# %% [markdown]
# ## Import do segundo arquivo
# Arquivo do google spreadsheet

# %% [markdown]
# ### Download do arquivo

# %%
## importação do google spreasheet API

# %% [markdown]
# ### Leitura do arquivo CSV

# %%
file = './Teste importador - usuarios.csv'
file2 = pandas.read_csv(file, sep=',')
file2.head()
# Out:
#      id             nome                  email        telefone  valor  \
# 0  8056       Nia Nickle  noodles@sbcglobal.net    555919295629  45.45
# 1  8094  Charisse Baltes          heine@aol.com             NaN  45,44
# 2  8087    Shaunna Myers         tezbo@yahoo.ca  (426) 296-8278      7
# 3  8019      Del Mayorga      aukjan@icloud.com  (264) 385-2009  45,44
# 4  8027   Kandis Marchan         lstein@mac.com  (209) 620-1483  10009
#
#   desconto
# 0       35
# 1       12
# 2       45
# 3        -
# 4        8

# %% [markdown]
# ## tratamento dos dados do segundo arquivo

# %%
file2['valor_com_desconto'] = (file2['valor'].apply(lambda x : validaCastNumerico(x)) - file2['desconto'].apply(lambda x : validaCastNumerico(x)))
file2['telefone'] = file2['telefone'].mask(pandas.isnull, '')
file2['telefone'] = file2['telefone'].apply(lambda x : (tratamentoTelefone(x) if not x == numpy.nan else ''))
file2['valor'] = file2['valor'].apply(lambda x : tratamentoValor(x))
file2['desconto'] = file2['desconto'].apply(lambda x : tratamentoValor((x if str(x).isdigit() else 0)))
file2['valor_com_desconto'] = file2['valor_com_desconto'].apply(lambda x : tratamentoValor(x))
file2.columns = defaultColumns
file2.head(5)
# Out:
#      id             name                  email            phone        value  \
# 0  8056       Nia Nickle  noodles@sbcglobal.net  +55555919295629     R$ 45,45
# 1  8094  Charisse Baltes          heine@aol.com              +55     R$ 45,44
# 2  8087    Shaunna Myers         tezbo@yahoo.ca    +554262968278      R$ 7,00
# 3  8019      Del Mayorga      aukjan@icloud.com    +552643852009     R$ 45,44
# 4  8027   Kandis Marchan         lstein@mac.com    +552096201483  R$ 10009,00
#
#    discount valor_com_desconto
# 0  R$ 35,00          R$ -35,00
# 1  R$ 12,00          R$ -12,00
# 2  R$ 45,00          R$ -38,00
# 3   R$ 0,00            R$ 0,00
# 4   R$ 8,00        R$ 10001,00

# %% [markdown]
# ## Import do terceiro arquivo
# Arquivo XML

# %%
file = './dataApr-1-2019 2.xml'

def getvalueofnode(node):
    return node.text if node is not None else None
 
parsed_xml = et.parse(file)
dfcols = ['user_id','name','email_user','phone','buy_value']
file3 = pandas.DataFrame(columns=dfcols)

for node in parsed_xml.getroot():
    user_id = node.find('user_id')
    name = node.find('name')
    email_user = node.find('email_user')
    phone = node.find('phone')
    buy_value = node.find('buy_value')

    file3 = file3.append(
        pandas.Series([getvalueofnode(user_id),
                   getvalueofnode(name), 
                   getvalueofnode(email_user),
                   getvalueofnode(phone),
                   getvalueofnode(buy_value)], index=dfcols),
        ignore_index=True)
file3.head()
# Out:
#   user_id             name                            email_user  \
# 0       1  Channing Hayden  cursus.et.magna@Nullamsuscipitest.ca
# 1       2       Baker Alea             dapibus@scelerisque.co.uk
# 2       3       Jack Kylie              dictum.Proin@necenim.net
# 3       4       Edan Jayme              Vivamus.nibh.dolor@a.edu
# 4       5    Hanna Kaitlin                          dui@nisl.net
#
#           phone buy_value
# 0  722 144-4062     96.55
# 1  851 730-0472     93.61
# 2  298 821-4445     23.42
# 3  123 288-9428     78.24
# 4  726 755-3600      4.17

# %% [markdown]
# ## tratamento dos dados do terceiro arquivo

# %%
file3['valor_com_desconto'] = (file3['buy_value'].apply(lambda x : float(x)))
file3['phone'] = file3['phone'].apply(lambda x : tratamentoTelefone(x))
file3['buy_value'] = file3['buy_value'].apply(lambda x : tratamentoValor(x))
file3['valor_com_desconto'] = file3['valor_com_desconto'].apply(lambda x : tratamentoValor(x))
file3['discount'] = 'R$ 0.00'
file3.columns = ['id', 'name', 'email', 'phone', 'value', 'valor_com_desconto', 'discount']
file3.head(5)
# Out:
#   id             name                                 email          phone  \
# 0  1  Channing Hayden  cursus.et.magna@Nullamsuscipitest.ca  +557221444062
# 1  2       Baker Alea             dapibus@scelerisque.co.uk  +558517300472
# 2  3       Jack Kylie              dictum.Proin@necenim.net  +552988214445
# 3  4       Edan Jayme              Vivamus.nibh.dolor@a.edu  +551232889428
# 4  5    Hanna Kaitlin                          dui@nisl.net  +557267553600
#
#       value valor_com_desconto discount
# 0  R$ 96,55           R$ 96,55  R$ 0.00
# 1  R$ 93,61           R$ 93,61  R$ 0.00
# 2  R$ 23,42           R$ 23,42  R$ 0.00
# 3  R$ 78,24           R$ 78,24  R$ 0.00
# 4   R$ 4,17            R$ 4,17  R$ 0.00

# %% [markdown]
# ## Juntando os e dataframes em um só

# %%
dataSetCompleto = pandas.concat([file1, file2, file3], sort=False)
dataSetCompleto.head(1000)
# Out:
#       id              name                                             email  \
# 0   1000     Cynthia Renee                   nulla@sitametconsectetuer.co.uk
# 1   1001       Kevin Zahir                                 Cras@justosit.org
# 2   1002     Marvin Tucker                          nec@nislsemconsequat.net
# 3   1003     Olympia Blake                                  malesuada@at.edu
# 4   1004     Wallace Ethan                     sem.molestie@urnasuscipit.net
# 5   1005       Colby Aline                ornare.sagittis@montesnascetur.net
# 6   1006     Carla Emerald                  Suspendisse.aliquet@nonmassa.edu
# 7   1007     Imogene Briar                   sed.turpis@nonvestibulumnec.org
# 8   1008      Haviva Yoshi                 in@consectetueradipiscingelit.edu
# 9   1009   Winter Honorato          enim.Mauris.quis@elitAliquamauctor.co.uk
# 10  1010        Gray Idola                        congue.In@Fuscealiquam.com
# 11  1011     Sawyer Angela              libero.dui.nec@acturpisegestas.co.uk
# 12  1012       Hilel Nyssa                                   purus@risus.com
# 13  1013     Nicole Kareem                       ante.iaculis@interdum.co.uk
# 14  1014      Clio Alfonso                        luctus.et@leoelementum.edu
# 15  1015   Anastasia Ahmed                       Donec.non.justo@eratSed.org
# 16  1016  Gabriel Nicholas                    Curabitur@tempordiamdictum.net
# 17  1017     Angela Vernon                             non.bibendum@vitae.ca
# 18  1018        Janna Tate                                   purus@ipsum.net
# 19  1019    Lynn Christine                            tellus.Aenean@nibh.com
# 20  1020      Blair Dexter                            Mauris@aliquamarcu.org
# 21  1021       Brenna Sean                     semper.et.lacinia@sitamet.net
# 22  1022       Jared Clark                        dolor.Fusce.mi@nullaIn.net
# 23  1023       Kadeem Hedy                             sit@disparturient.edu
# 24  1024      Quyn Phyllis                              quam@egestasnunc.org
# 25  1025     Audrey Travis  Maecenas.ornare.egestas@nasceturridiculusmus.com
# 26  1026       Jason Louis                      fringilla.Donec@mauris.co.uk
# 27  1027         Uta Kylee                  id.nunc.interdum@facilisiSed.net
# 28  1028        Nell Ivana                   id.blandit@malesuadaInteger.edu
# 29  1029        Tiger Edan                           ante.dictum@nonarcu.edu
# ..   ...               ...                                               ...
# 70    71     MacKensie Emi                        amet.lorem.semper@enim.com
# 71    72     Ocean Kennedy                 Morbi.quis@arcuAliquamultrices.ca
# 72    73     Sara Jennifer                       lectus@Quisqueporttitor.org
# 73    74     Craig Katelyn                              tellus@luctussit.edu
# 74    75      James Hamish                      fringilla.est@cursuset.co.uk
# 75    76       Darrel Iola                      mauris.rhoncus.id@atarcu.org
# 76    77        Nero Molly                                non@egestasa.co.uk
# 77    78     Tasha Brianna               tincidunt.congue.turpis@semeget.com
# 78    79    Denton Kristen                   natoque.penatibus.et@Integer.ca
# 79    80      Dante Brenna                       amet.ornare.lectus@ante.org
# 80    81        Lynn Ahmed                            sed.sapien@estNunc.com
# 81    82    Timothy Holmes                  mollis.Duis.sit@pellentesque.edu
# 82    83    Indigo Nichole                   auctor.odio@vestibulumneque.org
# 83    84    Gabriel Xavier                                   arcu@natoque.ca
# 84    85       Cruz Yoshio                                  semper@velit.edu
# 85    86      Asher Hamish                    Cras.sed.leo@vulputateeu.co.uk
# 86    87     Colton Jasper                   vitae.sodales@elitpretium.co.uk
# 87    88         Rina Reed                                 dui.quis@nunc.edu
# 88    89        Tanek Gail                             mauris.sapien@urna.ca
# 89    90      Pandora Berk                  interdum.Sed.auctor@eutellus.edu
# 90    91   Shana Geraldine                          venenatis.a@ametnulla.ca
# 91    92    Baxter Heather                   Aliquam.nisl@gravidanuncsed.edu
# 92    93    Marah Nomlanga                    blandit@sollicitudinorci.co.uk
# 93    94        Porter Ava           Aliquam.adipiscing.lobortis@Sednulla.ca
# 94    95       Wing Sophia                         Nulla.aliquet@erosNam.com
# 95    96      Palmer Lucas                           tincidunt@vulputate.com
# 96    97    Medge Garrison                          at@euodioPhasellus.co.uk
# 97    98  Alfreda Veronica                      Maecenas.libero.est@nunc.com
# 98    99    Buffy Angelica                                ipsum@Maecenas.net
# 99   100     Zachery Magee                    faucibus@Namconsequatdolor.com
#
#             phone     value  discount valor_com_desconto
# 0   +550517027535  R$ 75,82  R$ 66,00            R$ 9,82
# 1   +552823664062  R$ 44,54  R$ 23,00           R$ 21,54
# 2   +550590806768  R$ 17,12  R$ 74,00          R$ -56,88
# 3   +559286333253   R$ 6,15  R$ 33,00          R$ -26,85
# 4   +559943249907  R$ 99,76  R$ 49,00           R$ 50,76
# 5   +559688590017  R$ 37,98  R$ 37,00            R$ 0,98
# 6   +555848087730  R$ 66,84  R$ 97,00          R$ -30,16
# 7   +559578525089  R$ 34,16  R$ 64,00          R$ -29,84
# 8   +552913217760  R$ 67,18  R$ 57,00           R$ 10,18
# 9   +550525019786  R$ 88,89  R$ 79,00            R$ 9,89
# 10  +555056209686  R$ 54,27  R$ 97,00          R$ -42,73
# 11  +551526867824  R$ 47,56  R$ 77,00          R$ -29,44
# 12  +558272359672  R$ 47,49  R$ 65,00          R$ -17,51
# 13  +554129589152  R$ 21,49  R$ 73,00          R$ -51,51
# 14  +555963224153  R$ 62,02  R$ 52,00           R$ 10,02
# 15  +557999268828  R$ 95,22  R$ 18,00           R$ 77,22
# 16  +556202063879   R$ 5,60  R$ 72,00          R$ -66,40
# 17  +559933327608  R$ 61,74  R$ 25,00           R$ 36,74
# 18  +554943714705  R$ 66,90  R$ 83,00          R$ -16,10
# 19  +554845946191  R$ 49,86  R$ 63,00          R$ -13,14
# 20  +553363254822  R$ 82,99  R$ 90,00           R$ -7,01
# 21  +552463141191  R$ 15,38   R$ 1,00           R$ 14,38
# 22  +556787619317  R$ 84,07  R$ 28,00           R$ 56,07
# 23  +559079539678  R$ 63,41  R$ 31,00           R$ 32,41
# 24  +555860134901  R$ 55,53  R$ 45,00           R$ 10,53
# 25  +552292058656  R$ 70,12  R$ 42,00           R$ 28,12
# 26  +555233263033  R$ 81,51  R$ 53,00           R$ 28,51
# 27  +555089652989  R$ 71,49  R$ 10,00           R$ 61,49
# 28  +555101373934  R$ 67,47  R$ 24,00           R$ 43,47
# 29  +553146216707  R$ 20,18  R$ 11,00            R$ 9,18
# ..            ...       ...       ...                ...
# 70  +559337663912  R$ 66,59   R$ 0.00           R$ 66,59
# 71  +553864932419  R$ 73,51   R$ 0.00           R$ 73,51
# 72  +551944676354  R$ 41,11   R$ 0.00           R$ 41,11
# 73  +552305587304  R$ 23,33   R$ 0.00           R$ 23,33
# 74  +553677508785  R$ 69,74   R$ 0.00           R$ 69,74
# 75  +553073353875  R$ 45,97   R$ 0.00           R$ 45,97
# 76  +552266511614  R$ 12,44   R$ 0.00           R$ 12,44
# 77  +558396110994  R$ 22,50   R$ 0.00           R$ 22,50
# 78  +554495942907  R$ 53,35   R$ 0.00           R$ 53,35
# 79  +551209182346  R$ 72,91   R$ 0.00           R$ 72,91
# 80  +555208406975  R$ 33,72   R$ 0.00           R$ 33,72
# 81  +555570338592  R$ 85,45   R$ 0.00           R$ 85,45
# 82  +559063751301  R$ 99,32   R$ 0.00           R$ 99,32
# 83  +555832458887  R$ 69,65   R$ 0.00           R$ 69,65
# 84  +552621849435  R$ 86,00   R$ 0.00           R$ 86,00
# 85  +555189053641   R$ 6,13   R$ 0.00            R$ 6,13
# 86  +553579937651  R$ 15,18   R$ 0.00           R$ 15,18
# 87  +554481499802  R$ 30,65   R$ 0.00           R$ 30,65
# 88  +551122469242  R$ 47,82   R$ 0.00           R$ 47,82
# 89  +552544975579  R$ 93,63   R$ 0.00           R$ 93,63
# 90  +558539984504  R$ 35,37   R$ 0.00           R$ 35,37
# 91  +557268418477  R$ 76,19   R$ 0.00           R$ 76,19
# 92  +552596884945  R$ 17,99   R$ 0.00           R$ 17,99
# 93  +559491973729  R$ 38,73   R$ 0.00           R$ 38,73
# 94  +555031091798  R$ 75,03   R$ 0.00           R$ 75,03
# 95  +557938271680  R$ 64,31   R$ 0.00           R$ 64,31
# 96  +552642873845  R$ 59,14   R$ 0.00           R$ 59,14
# 97  +556236397032  R$ 12,26   R$ 0.00           R$ 12,26
# 98  +553105702421   R$ 1,70   R$ 0.00            R$ 1,70
# 99  +550823723422  R$ 54,85   R$ 0.00           R$ 54,85
#
# [299 rows x 7 columns]

# %% [markdown]
# ## Inserindo os dados em arquivo CSV

# %%
dataSetCompleto.to_csv(path_or_buf='./exportacao.csv',sep=';', index=False)
